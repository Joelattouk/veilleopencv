# %%
from jupyterthemes import get_themes
from jupyterthemes.stylefx import set_nb_theme

# %% [markdown]
# ## Demo de traitement de données avec OpenCV
# - analyse de la photo du verre rouge de Charly
#     - Lecture de l'image

# %%
! pip install opencv-python
# Out:
# ...
#      |████████████████████████████████| 50.4 MB 47 kB/s  eta 0:00:01     |█████████████████████▉          | 34.4 MB 388 kB/s eta 0:00:42
# ...

# %%
import cv2 as ocv

# %%
# Lecture de l'image de Charlyto
charl_im = ocv.imread('/home/machine/Downloads/WhatsApp Image 2021-04-19 at 17.23.05.jpeg')
charl_im.shape
# Out:
# (486, 1080, 3)

# %%
for i in [0, 1, 2]:
    if i == 0:
        print('ligne =', charl_im.shape[0])
    elif i == 1:
        print('colonne =', charl_im.shape[1] )
    else:
        print('stockage d\'octet =', charl_im.shape[2])
# Out:
# ligne = 486
# colonne = 1080
# stockage d'octet = 3

# %%
# le nombre de pixels
charl_im[400, 300]
# Out:
# array([105, 116, 124], dtype=uint8)

# %%
print("plus petit pixel = ", charl_im.min(), "\n\n")
print("plus grand pixel = ", charl_im.max())
# Out:
# plus petit pixel =  0
#
#
# plus grand pixel =  255

# %% [markdown]
# ####  selon la littérature la pluspart des pixels sont entre [0, 255]

# %%
import matplotlib.pyplot as plt

# %%
plt.title('Le Verre rouge de Charly', c='blue')
plt.imshow(charl_im[..., ::-1])
plt.show()
